# %% [markdown]
# # Obtain RR Interval from color component list from PPG signal

# %%
import cv2
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline
fps = 30.323427803

# %% [markdown]
# This function obtains a list of color component from txt file.

# %%
def readFromFile(fileName):
    l =numpy.loadtxt(fileName)
    return l[0], l[1], l[2]

# %% [markdown]
# This function runs through the color list, returns the peak that are local maxima for an interval of 2 times the frameThreshold. It returns the list of peaks. For exmple, if frameThreshold is 10, it returns only the maxima that are greater than the values of 10 frames before and those of 10 frames after.

# %%
def detectPeak(colorL, frameThreshold):
    peakL = list()
    colorlistLen = len(colorL)
    for i in range(1, colorlistLen-1):
        biggerThanPrevious = colorL[i] > colorL[i-1]
        biggerThanAfter = colorL[i] > colorL[i+1]
        #if it is a local maximum, then check if it is a RR peak by comparing its maxima interval to frameThreshold
        if biggerThanPrevious and biggerThanAfter:
            for k in range(2, frameThreshold+1):
                if i-k >= 0:
                    if not colorL[i] > colorL[i-k]:
                        #this is not a rr peak
                        break
                if i+k < colorlistLen:
                    if not colorL[i] > colorL[i+k]:
                        #this is not a rr peak
                        break
            else:
                #this IS a rr peak, store the array index
                peakL.append(i)
    return peakL

# %% [markdown]
# This function create the corresponding time coordinate from the list of rr intervals

# %%
def constructTimeListFromRRList(rrL):
    tL = list()
    tL.append(rrL[0])
    for i in range(1, len(rrL)):
        tL.append(tL[i-1]+rrL[i])
    return tL

# %% [markdown]
# This function graph the data.

# %%
def plot(inVarList, deVarList, inVarName, deVarName, yBegin=0, yEnd=1.5):
    plt.plot(inVarList, deVarList)
    plt.xlabel(inVarName)
    plt.ylabel(deVarName)
    plt.title(inVarName+' vs '+deVarName)
    plt.ylim(yBegin, yEnd)
    plt.show()

# %% [markdown]
# Here we begin Graphing rr intervals from green from a.txt. We first use threshold of 25 frames.

# %%
rL, gL, bL = readFromFile('a.txt')
peakL = detectPeak(gL, 25)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  28 peaks.

# %% [markdown]
# For threshold of 17 frames

# %%
peakL = detectPeak(gL, 17)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  31 peaks.

# %% [markdown]
# For threshold of 13 frames

# %%
peakL = detectPeak(gL, 13)
print "There are", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are 32 peaks.

# %% [markdown]
# For threshold of 4 frames

# %%
peakL = detectPeak(gL, 4)
print "There are", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are 37 peaks.

# %% [markdown]
# I counted the peaks on the actually data. There are 32 peaks. A threshold of 13 frames is most accurate.

# %% [markdown]
# # For the second video

# %% [markdown]
# We first use threshold of 25 frames.

# %%
rL, gL, bL = readFromFile('b.txt')
peakL = detectPeak(gL, 25)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  21 peaks.

# %% [markdown]
# Threshold 17

# %%
peakL = detectPeak(gL, 17)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  33 peaks.

# %% [markdown]
# threshold of 13 frames

# %%
peakL = detectPeak(gL, 13)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  33 peaks.

# %% [markdown]
# Threshold 5 frames.

# %%
peakL = detectPeak(gL, 5)
print "There are ", str(len(peakL)), "peaks."
#construct the rr interval list
rrL = [ (peakL[i]-peakL[i-1])/fps for i in range(1, len(peakL))]
tL = constructTimeListFromRRList(rrL)
plot(tL, rrL, 'Time(s)', 'RR Interval(s)')
# Out:
# There are  36 peaks.

# %% [markdown]
# I counted the actuall RR peaks. There are 33 peaks. So in this case, the theshold of 17 and 13 works best.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Around 11 to 13 frames of before the peak and after the peak, for a total of 22 or 26 frames, detect most accurate RR Intervals.
